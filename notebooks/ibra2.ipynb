# %%
import pandas as pd
df = pd.read_csv('../data/FAOSTAT_Emissions_E_All.csv')
df.head()
# Out:
#    Area Code Area Code (M49)         Area  Item Code           Item  \
# 0          2            '004  Afghanistan       5064  Crop Residues
# 1          2            '004  Afghanistan       5064  Crop Residues
# 2          2            '004  Afghanistan       5064  Crop Residues
# 3          2            '004  Afghanistan       5064  Crop Residues
# 4          2            '004  Afghanistan       5064  Crop Residues
#
#    Element Code                           Element  Source Code      Source  \
# 0          7234            Direct emissions (N2O)         3050  FAO TIER 1
# 1          7236          Indirect emissions (N2O)         3050  FAO TIER 1
# 2          7230                   Emissions (N2O)         3050  FAO TIER 1
# 3        724313  Emissions (CO2eq) from N2O (AR5)         3050  FAO TIER 1
# 4        723113           Emissions (CO2eq) (AR5)         3050  FAO TIER 1
#
#          Unit  ...  Y2020N Y2021  Y2021F  Y2021N     Y2030  Y2030F  Y2030N  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1326 entries, 0 to 1325
# Columns: 199 entries, Area Code to Y2050N
# dtypes: float64(106), int64(4), object(89)
# memory usage: 2.0+ MB

# %%
df.shape
# Out:
# (1326, 199)

# %%
df.isnull().sum()
# Out:
# Area Code             0
# Area Code (M49)       0
# Area                  0
# Item Code             0
# Item                  0
#                    ...
# Y2030F              993
# Y2030N             1326
# Y2050               993
# Y2050F              993
# Y2050N             1326
# Length: 199, dtype: int64

# %%
df1 = df.groupby('Element')["Area"].count()
df1.head()
# Out:
# Element
# Direct emissions (N2O)               31
# Emissions (CH4)                     196
# Emissions (CO2)                     154
# Emissions (CO2eq) (AR5)             268
# Emissions (CO2eq) from CH4 (AR5)    192
# Name: Area, dtype: int64

# %%
df2 = df.groupby('Area')["Element"].count()
df2
# Out:
# Area
# Afghanistan            224
# Albania                239
# Algeria                235
# American Samoa         101
# Andorra                133
# Angola                 214
# Anguilla               145
# Antigua and Barbuda     35
# Name: Element, dtype: int64

# %%
dfco2 = df[df["Element"]=='Emissions (CO2)']
dfco2.head(2)
# Out:
#     Area Code Area Code (M49)         Area  Item Code  \
# 48          2            '004  Afghanistan      67292
# 55          2            '004  Afghanistan       6994
#
#                            Item  Element Code          Element  Source Code  \
# 48  Drained organic soils (CO2)          7273  Emissions (CO2)         3050
# 55           On-farm energy use          7273  Emissions (CO2)         3050
#
#         Source        Unit  ...  Y2020N Y2021  Y2021F  Y2021N Y2030  Y2030F  \
# 48  FAO TIER 1  kilotonnes  ...     NaN   NaN     NaN     NaN   NaN     NaN
# 55  FAO TIER 1  kilotonnes  ...     NaN   NaN     NaN     NaN   NaN     NaN
#
#     Y2030N Y2050  Y2050F  Y2050N
# 48     NaN   NaN     NaN     NaN
# 55     NaN   NaN     NaN     NaN
#
# [2 rows x 199 columns]

# %%
df4 = dfco2.groupby('Area')["Element"].count()
df4
# Out:
# Area
# Afghanistan       25
# Albania           27
# Algeria           26
# American Samoa    13
# Andorra           19
# Angola            24
# Anguilla          20
# Name: Element, dtype: int64

# %%
dfch4 = df[df["Element"]=='Emissions (CH4)']
dfch4.head(2)
# Out:
#    Area Code Area Code (M49)         Area  Item Code                     Item  \
# 5          2            '004  Afghanistan       5060         Rice Cultivation
# 8          2            '004  Afghanistan       5066  Burning - Crop residues
#
#    Element Code          Element  Source Code      Source        Unit  ...  \
# 5          7225  Emissions (CH4)         3050  FAO TIER 1  kilotonnes  ...
# 8          7225  Emissions (CH4)         3050  FAO TIER 1  kilotonnes  ...
#
#    Y2020N Y2021  Y2021F  Y2021N    Y2030  Y2030F  Y2030N    Y2050  Y2050F  \
# 5     NaN   NaN     NaN     NaN  32.3685       E     NaN  41.3331       E
# 8     NaN   NaN     NaN     NaN   3.4935       E     NaN   3.4857       E
#
#    Y2050N
# 5     NaN
# 8     NaN
#
# [2 rows x 199 columns]

# %%
df5 = dfch4.groupby('Area')["Element"].count()
df5
# Out:
# Area
# Afghanistan            33
# Albania                35
# Algeria                34
# American Samoa         16
# Andorra                20
# Angola                 30
# Anguilla               23
# Antigua and Barbuda     5
# Name: Element, dtype: int64

# %%
dfco2eq = df[df["Element"]=='Emissions (CO2eq) (AR5)']
dfco2eq.head(2)
# Out:
#    Area Code Area Code (M49)         Area  Item Code              Item  \
# 4          2            '004  Afghanistan       5064     Crop Residues
# 7          2            '004  Afghanistan       5060  Rice Cultivation
#
#    Element Code                  Element  Source Code      Source        Unit  \
# 4        723113  Emissions (CO2eq) (AR5)         3050  FAO TIER 1  kilotonnes
# 7        723113  Emissions (CO2eq) (AR5)         3050  FAO TIER 1  kilotonnes
#
#    ...  Y2020N Y2021  Y2021F  Y2021N     Y2030  Y2030F  Y2030N      Y2050  \
# 4  ...     NaN   NaN     NaN     NaN  497.8929       E     NaN   629.4047
# 7  ...     NaN   NaN     NaN     NaN  906.3176       E     NaN  1157.3275
#
#    Y2050F  Y2050N
# 4       E     NaN
# 7       E     NaN
#
# [2 rows x 199 columns]

# %%
df6 = dfco2eq.groupby('Area')["Element"].count()
df6
# Out:
# Area
# Afghanistan            47
# Albania                47
# Algeria                47
# American Samoa         22
# Andorra                27
# Angola                 42
# Anguilla               29
# Antigua and Barbuda     7
# Name: Element, dtype: int64

# %%
dff = df[df["Element"]=='Emissions (CO2eq) from CH4 (AR5)']
dff.head(2)
# Out:
#     Area Code Area Code (M49)         Area  Item Code  \
# 6           2            '004  Afghanistan       5060
# 12          2            '004  Afghanistan       5066
#
#                        Item  Element Code                           Element  \
# 6          Rice Cultivation        724413  Emissions (CO2eq) from CH4 (AR5)
# 12  Burning - Crop residues        724413  Emissions (CO2eq) from CH4 (AR5)
#
#     Source Code      Source        Unit  ...  Y2020N Y2021  Y2021F  Y2021N  \
# 6          3050  FAO TIER 1  kilotonnes  ...     NaN   NaN     NaN     NaN
# 12         3050  FAO TIER 1  kilotonnes  ...     NaN   NaN     NaN     NaN
#
#        Y2030  Y2030F  Y2030N      Y2050  Y2050F  Y2050N
# 6   906.3176       E     NaN  1157.3275       E     NaN
# 12   97.8173       E     NaN    97.5996       E     NaN
#
# [2 rows x 199 columns]

# %%
df7 = dff.groupby('Area')["Element"].count()
df7
# Out:
# Area
# Afghanistan            32
# Albania                34
# Algeria                33
# American Samoa         16
# Andorra                20
# Angola                 29
# Anguilla               23
# Antigua and Barbuda     5
# Name: Element, dtype: int64

# %%
df.head()
# Out:
#    Area Code Area Code (M49)         Area  Item Code           Item  \
# 0          2            '004  Afghanistan       5064  Crop Residues
# 1          2            '004  Afghanistan       5064  Crop Residues
# 2          2            '004  Afghanistan       5064  Crop Residues
# 3          2            '004  Afghanistan       5064  Crop Residues
# 4          2            '004  Afghanistan       5064  Crop Residues
#
#    Element Code                           Element  Source Code      Source  \
# 0          7234            Direct emissions (N2O)         3050  FAO TIER 1
# 1          7236          Indirect emissions (N2O)         3050  FAO TIER 1
# 2          7230                   Emissions (N2O)         3050  FAO TIER 1
# 3        724313  Emissions (CO2eq) from N2O (AR5)         3050  FAO TIER 1
# 4        723113           Emissions (CO2eq) (AR5)         3050  FAO TIER 1
#
#          Unit  ...  Y2020N Y2021  Y2021F  Y2021N     Y2030  Y2030F  Y2030N  \
# ...
